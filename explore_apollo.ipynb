# %%
import polars as pl
import pandas as pd
import numpy as np
from pathlib import Path
import csv
import tqdm
import os


from IPython.display import display

# %%
# Usage

def preprocess(file_path, output_file):
    # Determine total file size for progress tracking
    file_size = os.path.getsize(file_path)
    # max_lines = 100000
    line_index = 0  
    bad_rows = 0
    with open(file_path, 'rb') as infile, open(output_file, 'w', newline='', encoding='utf-8') as outfile:
        writer = csv.writer(outfile)
        progress = tqdm.tqdm(total=file_size, desc="Processing File", unit="B", unit_scale=True)

        # Initialize control variables
        current_row = []
        processed_bytes = 0

        # Read and process the file line by line in binary mode
        while True:
            line = infile.readline()
            if not line:
                break

            processed_bytes += len(line)
            progress.update(len(line))
            
            # Decode line, handle escaped tabs and internal newlines
            decoded_line = line.decode('utf-8')
            decoded_line = decoded_line.replace('\\\\t', '<ESC_TAB>').replace('\r\n', '<ESC_NEWLINE>').replace('\r', '<ESC_CR>')

            # Split on unescaped tabs, process each part
            parts = decoded_line.split('\t')
            for part in parts:
                normalized_part = part.replace('<ESC_TAB>', '\t').replace('<ESC_NEWLINE>', '\r\n').replace('<ESC_CR>', '\r').strip()
                current_row.append(normalized_part)

            # If the line ends with a newline (split condition), it means end of a row
            if decoded_line.endswith('\n'):
                # Write the completed row to the file
                if len(current_row) != 51:
                    bad_rows += 1
                writer.writerow(current_row)
                current_row = []
            else:
                # print(f"Line {line_index} does not end with a newline, continuing to next line")
                pass

            line_index += 1
            # if line_index > max_lines:
            #     break

        # Write any remaining data in current_row to the file (in case the last line does not end with a newline)
        if current_row:
            writer.writerow(current_row)

        progress.close()
    print(f"Bad rows: {bad_rows}/{line_index} ({bad_rows/line_index*100:.2f}%)")

apollo_file_path = Path('data/apollo/Apollo 200 Million 3_3-008.csv')
apollo_output_file = Path('data/apollo/Apollo 200 Million 3_3-008_corrected_2.csv')

if not apollo_output_file.exists():
    preprocess(apollo_file_path, apollo_output_file)
    
    
apollo2_file_path = Path('data/apollo/Apollo 200 Million 2_3-002.csv')
apollo2_output_file = Path('data/apollo/Apollo 200 Million 2_3-002_corrected.csv')

if not apollo2_output_file.exists():
    preprocess(apollo2_file_path, apollo2_output_file)

# %%
apollo_companies_df = pl.read_csv('data/apollo/Apollo 200 Million 3_3-008_corrected_2.csv', truncate_ragged_lines=True, infer_schema_length=0)

# %%
apollo_people_df = pl.read_csv('data/apollo/Apollo 200 Million 2_3-002.csv', truncate_ragged_lines=True, infer_schema_length=0)

# %%
combined_df = pl.concat([pl.read_csv(file, ignore_errors=True) for file in corrected_csv_files])

# %%
print(f"Bad rows {combined_df['LEGALENTITYCONGRESSIONALDISTRICT'].is_null().sum()}")

# Drop rows with missing 'LEGALENTITYCONGRESSIONALDISTRICT' values
combined_df = combined_df.filter(combined_df['LEGALENTITYCONGRESSIONALDISTRICT'].is_not_null())

print(f"Number of rows after dropping missing 'LEGALENTITYCONGRESSIONALDISTRICT' values: {len(combined_df)}")
# Out:
# Bad rows 850
# Number of rows after dropping missing 'LEGALENTITYCONGRESSIONALDISTRICT' values: 3765391

# %%
import os
import tqdm

def check_line_endings(file_path):
    line_endings = {
        'LF': 0,
        'CRLF': 0,
        'CR': 0,
        'None': 0  # To handle files that might not end with a newline character
    }

    file_size = os.path.getsize(file_path)
    processed_bytes = 0

    with open(file_path, 'rb') as file:
        # Set up the tqdm progress bar
        with tqdm.tqdm(total=file_size, desc="Processing file", unit="B", unit_scale=True) as pbar:
            while True:
                line = file.readline()
                if not line:
                    break  # End of file

                processed_bytes += len(line)
                pbar.update(len(line))

                # Check line endings
                if line.endswith(b'\r\n'):
                    line_endings['CRLF'] += 1
                elif line.endswith(b'\n'):
                    line_endings['LF'] += 1
                elif line.endswith(b'\r'):
                    line_endings['CR'] += 1

    for ending, count in line_endings.items():
        print(f"Lines ending with {ending}: {count}")

# Usage
file_path = 'data/apollo/Apollo 200 Million 3_3-008.csv'
check_line_endings(file_path)
# Out:
# Processing file: 100%|██████████| 10.2G/10.2G [00:10<00:00, 967MB/s]
# Lines ending with LF: 5593564
# Lines ending with CRLF: 475969
# Lines ending with CR: 0
# Lines ending with None: 0

# %%
import os
import tqdm

def check_line_endings(file_path, buffer_size=100000):
    line_endings = {
        'LF': 0,
        'CRLF': 0,
        'CR': 0,
        'None': 0
    }

    
    file_size = os.path.getsize(file_path)
    max_file_size = 100000000

    file_size = min(file_size, max_file_size)
    total_chunks = (file_size // buffer_size) + (1 if file_size % buffer_size != 0 else 0)


    last_char = b''
    with open(file_path, 'rb') as file:
        # Set up the tqdm progress bar
        with tqdm.tqdm(total=total_chunks, desc="Processing file") as pbar:
            buffer = file.read(buffer_size)
            while buffer:
                for char in buffer:
                    if char == ord('\n'):
                        if last_char == ord('\r'):
                            line_endings['CRLF'] += 1
                        else:
                            line_endings['LF'] += 1
                    elif last_char == ord('\r'):  # This carriage return was not followed by a newline
                        line_endings['CR'] += 1
                        print(f"CR found at {file.tell()} on line {line_endings['LF'] - line_endings['CRLF']}")
                    last_char = char

                buffer = file.read(buffer_size)
                pbar.update(1)  # Update progress bar after processing each buffer
                if file.tell() > max_file_size:
                    break

    # Check if the very last character was a CR that wasn't followed by a newline
    if last_char == ord('\r'):
        line_endings['CR'] += 1

    for ending, count in line_endings.items():
        print(f"Lines ending with {ending}: {count}")

# Usage
file_path = 'data/apollo/Apollo 200 Million 3_3-008.csv'
check_line_endings(file_path)
# Out:
# Processing file:  13%|█▎        | 128/1000 [00:01<00:07, 118.06it/s]
# CR found at 11300000 on line 4454
# CR found at 12200000 on line 4814
# CR found at 12200000 on line 4814
# Processing file:  24%|██▎       | 237/1000 [00:02<00:06, 115.34it/s]
# CR found at 22400000 on line 8825
# CR found at 22400000 on line 8825
# CR found at 22400000 on line 8825
# CR found at 22400000 on line 8825
# CR found at 22400000 on line 8825
# CR found at 22400000 on line 8825
# Processing file:  57%|█████▊    | 575/1000 [00:05<00:03, 115.14it/s]
# CR found at 56300000 on line 21484
# Processing file:  68%|██████▊   | 683/1000 [00:05<00:02, 113.70it/s]
# CR found at 67100000 on line 25543
# Processing file:  78%|███████▊  | 779/1000 [00:06<00:01, 113.14it/s]
# CR found at 76300000 on line 29026
# CR found at 76300000 on line 29026
# CR found at 76300000 on line 29026
# Processing file: 100%|██████████| 1000/1000 [00:08<00:00, 113.65it/s]
# CR found at 97200000 on line 37157
# CR found at 97200000 on line 37157
# CR found at 97200000 on line 37157
# CR found at 97200000 on line 37157
# Lines ending with LF: 41346
# Lines ending with CRLF: 3042
# Lines ending with CR: 18
# Lines ending with None: 0

# %%
def preprocess(file_path, output_file):
    # Determine total file size for progress tracking
    file_size = os.path.getsize(file_path)
    # max_lines = 100000
    line_index = 0  
    bad_rows = 0
    with open(file_path, 'rb') as infile, open(output_file, 'w', newline='', encoding='utf-8') as outfile:
        writer = csv.writer(outfile)
        progress = tqdm.tqdm(total=file_size, desc="Processing File", unit="B", unit_scale=True)

        # Initialize control variables
        current_row = []
        processed_bytes = 0

        # Read and process the file line by line in binary mode
        while True:
            line = infile.readline()
            if not line:
                break

            processed_bytes += len(line)
            progress.update(len(line))
            
            # Decode line, handle escaped tabs and internal newlines
            decoded_line = line.decode('utf-8')
            decoded_line = decoded_line.replace('\\\\t', '<ESC_TAB>').replace('\r\n', '<ESC_NEWLINE>').replace('\r', '<ESC_CR>')

            # Split on unescaped tabs, process each part
            parts = decoded_line.split('\t')
            for part in parts:
                normalized_part = part.replace('<ESC_TAB>', '\t').replace('<ESC_NEWLINE>', '\r\n').replace('<ESC_CR>', '\r').strip()
                current_row.append(normalized_part)

            # If the line ends with a newline (split condition), it means end of a row
            if decoded_line.endswith('\n'):
                # Write the completed row to the file
                if len(current_row) != 51:
                    bad_rows += 1
                writer.writerow(current_row)
                current_row = []
            else:
                # print(f"Line {line_index} does not end with a newline, continuing to next line")
                pass

            line_index += 1
            # if line_index > max_lines:
            #     break

        # Write any remaining data in current_row to the file (in case the last line does not end with a newline)
        if current_row:
            writer.writerow(current_row)

        progress.close()
    print(f"Bad rows: {bad_rows}/{line_index} ({bad_rows/line_index*100:.2f}%)")

# Usage
file_path = 'data/apollo/Apollo 200 Million 3_3-008.csv'
output_file = 'data/apollo/Apollo 200 Million 3_3-008_corrected_2.csv'
preprocess(file_path, output_file)
# Out:
# Processing File: 100%|██████████| 10.2G/10.2G [04:09<00:00, 40.9MB/s]
# Bad rows: 331105/6069533 (5.46%)

# %%
apollo_df = pl.read_csv('data/apollo/Apollo 200 Million 3_3-008_corrected_2.csv', truncate_ragged_lines=True, infer_schema_length=0)

# %%
apollo_df['_score'].value_counts(sort=True)
# Out:
# shape: (60_282, 2)
# ┌─────────────────────────────────┬─────────┐
# │ _score                          ┆ count   │
# │ ---                             ┆ ---     │
# │ str                             ┆ u32     │
# ╞═════════════════════════════════╪═════════╡
# │ 1                               ┆ 5262931 │
# │ null                            ┆ 201116  │
# │ person                          ┆ 26833   │
# │ people_v7                       ┆ 18247   │
# │ contact                         ┆ 9704    │
# │ …                               ┆ …       │
# │ 593cab21a6da9820b5781b21        ┆ 1       │
# │ 57db9b6ca6da986863071df7        ┆ 1       │
# │ {'type': 'envelope', 'coordina… ┆ 1       │
# │ 54aa8f4a7468690377d1480b        ┆ 1       │
# │ Toledo, Ohio                    ┆ 1       │
# └─────────────────────────────────┴─────────┘

# %%
pd.read_csv('data/apollo/Apollo 200 Million 3_3-008_corrected_2.csv')
# Out:
#                   organization_id          organization_name  \
# 0        54a11ef769702d8ccc8ab201             United Nations
# 1        54a1366a69702d46f00b1f01  Bina Nusantara University
# 2        54a12ae469702d9313fb6402      Despacho Presidencial
# 3        54a12af269702d9b8b8d5e02              Independiente
# 4        54a127c769702d8cfc25f600                  Banco Bci
# ...                           ...                        ...
# 5515454                       NaN                  people_v7
# 5515455                       NaN                  people_v7
# 5515456                       NaN                  people_v7
# 5515457                       NaN                  people_v7
# 5515458                       NaN                  people_v7
#
#         organization_revenue_in_thousands_int  \
# 0                                         NaN
# 1                                       35000
# 2                                         NaN
# 3                                         NaN
# 4                                     1800000
# ...                                       ...
# 5515454                                person
# 5515455                                person
# 5515456                                person
# 5515457                                person
# 5515458                                person
#
#         organization_retail_location_count organization_public_symbol  \
# 0                                      NaN                        NaN
# 1                                      NaN                        NaN
# 2                                      NaN                        NaN
# 3                                      NaN                        NaN
# 4                                      NaN                        NaN
# ...                                    ...                        ...
# 5515454           54a9ef4d7468693399bb4b1b                          1
# 5515455           54c229d17468697af7abcd80                          1
# 5515456           57df4d10a6da980ad8f08660                          1
# 5515457           54a1275569702db878b42e00                          1
# 5515458           57e093e6a6da981c55f4299d                          1
#
#         organization_linkedin_company_size_tag_ids  \
# 0                     ['5567e0c37369641233df0600']
# 1                     ['5567cd517369643981040000']
# 2                     ['5567cd4a73696453e12f0000']
# 3                     ['5567e10673696418751f0100']
# 4                     ['5567e0c37369641233df0600']
# ...                                            ...
# 5515454                   55e85115f3e5bb7f1e000539
# 5515455                   56d4e47cf3e5bb07050018f6
# 5515456                   54a134f769702d3e830b6900
# 5515457                   5592101d736964186fd84800
# 5515458                   559215707369641865b25900
#
#           organization_founded_year organization_alexa_ranking  \
# 0                              1945                       1627
# 1                              1974                      31496
# 2                               NaN                        NaN
# 3                               NaN                        NaN
# 4                              1937                      12353
# ...                             ...                        ...
# 5515454           Bittersweet Acres                        NaN
# 5515455   DingSen Industry Co., Ltd                        NaN
# 5515456              Colors of Life                        NaN
# 5515457  ZEMS ENTERTAINMENT LIMITED                        NaN
# 5515458                  advisor hr                        NaN
#
#         organization_num_current_employees  \
# 0                                    21789
# 1                                     1175
# 2                                       89
# 3                                    89754
# 4                                     4360
# ...                                    ...
# 5515454                                NaN
# 5515455                                NaN
# 5515456                                NaN
# 5515457                                NaN
# 5515458                                NaN
#
#                             organization_relevant_keywords  ...  \
# 0        ['development', 'peacekeeping', 'peace & secur...  ...
# 1        ['accounting', 'architecture', 'art design', '...  ...
# 2                            ['government administration']  ...
# 3                                          ['photography']  ...
# 4        ['financial service', 'investors', 'banking', ...  ...
# ...                                                    ...  ...
# 5515454                                                NaN  ...
# 5515455                                                NaN  ...
# 5515456                                                NaN  ...
# 5515457                                                NaN  ...
# 5515458                                                NaN  ...
#
#         organization_hq_location_postal_code  \
# 0                                      10017
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 5515454                             LaGrange
# 5515455                                  NaN
# 5515456                                  NaN
# 5515457                               London
# 5515458                                  NaN
#
#                           organization_hq_location_geojson  \
# 0        {'type': 'envelope', 'coordinates': [[-73.9682...
# 1        {'type': 'envelope', 'coordinates': [[106.7822...
# 2        {'type': 'envelope', 'coordinates': [[-74.9376...
# 3                                                      NaN
# 4        {'type': 'envelope', 'coordinates': [[-70.5561...
# ...                                                    ...
# 5515454                                  LaGrange, Indiana
# 5515455                                                NaN
# 5515456                                                NaN
# 5515457                             London, United Kingdom
# 5515458                                                NaN
#
#         organization_total_funding_long organization_latest_funding_stage_cd  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
# ...                                 ...                                  ...
# 5515454                         Indiana                          Indiana, US
# 5515455                             NaN                                  NaN
# 5515456                             NaN                                  NaN
# 5515457                         England              England, United Kingdom
# 5515458                             NaN                                  NaN
#
#         organization_latest_funding_round_amount_long  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 5515454                                 United States
# 5515455                                           NaN
# 5515456                                           NaN
# 5515457                                United Kingdom
# 5515458                                           NaN
#
#         organization_latest_funding_round_date  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 5515454                                  46761
# 5515455                                    NaN
# 5515456                                    NaN
# 5515457                                 E7 9AL
# 5515458                                    NaN
#
#                                                     _index   _type  \
# 0                                                people_v7  person
# 1                                                people_v7  person
# 2                                                people_v7  person
# 3                                                people_v7  person
# 4                                                people_v7  person
# ...                                                    ...     ...
# 5515454  {'type': 'envelope', 'coordinates': [[-85.4247...     NaN
# 5515455                                                NaN     NaN
# 5515456                                                NaN     NaN
# 5515457  {'type': 'envelope', 'coordinates': [[0.013332...     NaN
# 5515458                                                NaN     NaN
#
#                               _id _score
# 0        54a98ccd74686930ad4b4714      1
# 1        54a586547468692fa266469a      1
# 2        54ebba33746869444cfd4117      1
# 3        54c1fb3074686916396e6d66      1
# 4        54a226aa74686930c2762311      1
# ...                           ...    ...
# 5515454                       NaN    NaN
# 5515455                       NaN    NaN
# 5515456                       NaN    NaN
# 5515457                       NaN    NaN
# 5515458                       NaN    NaN
#
# [5515459 rows x 51 columns]

# %%
# apollo_dir = data_dir / 'apollo'

# apollo_csv_files = []

# for csv_file in apollo_dir.rglob('*.csv'):
#     apollo_csv_files.append(csv_file)
    

# print(f"Number of Apollo CSV files: {len(apollo_csv_files)}")

# # Function to read only the first row (header) of a CSV to check consistency
# def read_header(file):
#     try:
#         df = pl.read_csv(file, has_header=True, new_columns=None, n_rows=0, infer_schema_length=0)
#         return df.schema
#     except Exception as e:
#         print(f"Error reading {file}: {e}")
#         return None
    
# headers = [read_header(file) for file in apollo_csv_files]
# first_header = headers[0]

# for i, header in enumerate(headers):
#     if header != first_header:
#         print(f"Header {i} do not match across files.")
#         break

# if all(header == first_header for header in headers):
#     print("All headers match.")
# else:
#     raise ValueError("Headers do not match across files.")

# # Function to read a CSV file with all data as string
# def load_csv_as_string(file):
#     try:
#         return pl.read_csv(file, has_header=True, infer_schema_length=0)
#     except Exception as e:
#         print(f"Failed to load {file}: {e}")
#         return None

# # Load all data treating everything as strings and concatenate
# appolo_df = pl.concat([pl.read_csv(file, has_header=True, infer_schema_length=0) for file in apollo_csv_files])#, how='diagonal')

# print(f"Total rows in concatenated dataframe: {len(appolo_df)}")

# %%
interesting_cols = ['AWARDEEORRECIPIENTLEGALENTITYNAME', 'LEGALENTITYADDRLINE1', 'LEGALENTITYCITYNAME', 'LEGALENTITYSTATECD', 'LEGALENTITYZIP5']

# %%
combined_df
# Out:
# shape: (3_765_391, 45)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ ACTIONTYP ┆ ACTIONDAT ┆ ASSISTANC ┆ RECORDTYP ┆ … ┆ NONFEDERA ┆ FACEVALUE ┆ ORIGINALL ┆ BUSINESS │
# │ E         ┆ E         ┆ ETYPE     ┆ E         ┆   ┆ LFUNDINGA ┆ OFDIRECTL ┆ OANSUBSID ┆ FUNDSIND │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ MOUNT     ┆ OANORLOAN ┆ YCOST     ┆ ICATOR   │
# │ str       ┆ i64       ┆ i64       ┆ i64       ┆   ┆ ---       ┆ GUA…      ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆ ---       ┆ f64       ┆ str      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ f64       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ A         ┆ 20200803  ┆ 7         ┆ 2         ┆ … ┆ null      ┆ 144000.0  ┆ 19612.8   ┆ NON      │
# │ A         ┆ 20200803  ┆ 7         ┆ 2         ┆ … ┆ null      ┆ 25300.0   ┆ 3445.86   ┆ NON      │
# │ A         ┆ 20200803  ┆ 7         ┆ 2         ┆ … ┆ null      ┆ 100000.0  ┆ 13620.0   ┆ NON      │
# │ A         ┆ 20200803  ┆ 7         ┆ 2         ┆ … ┆ null      ┆ 28600.0   ┆ 3895.32   ┆ NON      │
# │ A         ┆ 20200803  ┆ 7         ┆ 2         ┆ … ┆ null      ┆ 98400.0   ┆ 13402.08  ┆ NON      │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ A         ┆ 20200828  ┆ 7         ┆ 2         ┆ … ┆ null      ┆ 25000.0   ┆ 3405.0    ┆ NON      │
# │ A         ┆ 20200828  ┆ 7         ┆ 2         ┆ … ┆ null      ┆ 15000.0   ┆ 2043.0    ┆ NON      │
# │ A         ┆ 20200827  ┆ 7         ┆ 2         ┆ … ┆ null      ┆ 25000.0   ┆ 3405.0    ┆ NON      │
# │ A         ┆ 20200828  ┆ 7         ┆ 2         ┆ … ┆ null      ┆ 1700.0    ┆ 231.54    ┆ NON      │
# │ A         ┆ 20200827  ┆ 7         ┆ 2         ┆ … ┆ null      ┆ 20000.0   ┆ 2724.0    ┆ NON      │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
import fuzzywuzzy

# %%
combined_df['AWARDEEORRECIPIENTLEGALENTITYNAME']
# Out:
# shape: (3_765_391,)
# Series: 'AWARDEEORRECIPIENTLEGALENTITYNAME' [str]
# [
# 	"AKIKO'S SUSHI BAR INC."
# 	"DITZLER GENERAL CONTRACTING IN…
# 	"HERMAN CLEANERS, LLC"
# 	"RSM REALTY, LLC"
# 	"PINK PALETTE ARTISTS LLC"
# 	…
# 	"Saiko Excavation LLC"
# 	"Baryonnoh Vision"
# 	"EW Real Estate LLC"
# 	"MAZA ASSOCIATES LLC"
# 	"Raymond alcaraz"
# ]

# %%
apollo_df['organization_name']
# Out:
# shape: (5_593_563,)
# Series: 'organization_name' [str]
# [
# 	"United Nations"
# 	"Bina Nusantara University"
# 	"Despacho Presidencial"
# 	"Independiente"
# 	"Banco Bci"
# 	…
# 	"Bittersweet Acres"
# 	"DingSen Industry Co., Ltd"
# 	"Colors of Life"
# 	"ZEMS ENTERTAINMENT LIMITED"
# 	"advisor hr"
# ]

# %%
# sampled_name = combined_df['AWARDEEORRECIPIENTLEGALENTITYNAME'].sample(n=100, with_replacement=False)#.apply(lambda x: x.lower())
sampled_name = combined_df['AWARDEEORRECIPIENTLEGALENTITYNAME'].head()
# lower case in polar
sampled_names_lower_case = sampled_name.str.to_lowercase()

company_names_lower_case = apollo_df['organization_name'].str.to_lowercase()

# %%
sampled_names_lower_case
# Out:
# shape: (10,)
# Series: 'AWARDEEORRECIPIENTLEGALENTITYNAME' [str]
# [
# 	"akiko's sushi bar inc."
# 	"ditzler general contracting in…
# 	"herman cleaners, llc"
# 	"rsm realty, llc"
# 	"pink palette artists llc"
# 	"mainsource llc"
# 	"beth preddy public relations i…
# 	"avenir thinking, inc."
# 	"herman green"
# 	"gahanna sports factory llc"
# ]

# %%
combined_df.head()
# Out:
# shape: (5, 45)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ ACTIONTYP ┆ ACTIONDAT ┆ ASSISTANC ┆ RECORDTYP ┆ … ┆ NONFEDERA ┆ FACEVALUE ┆ ORIGINALL ┆ BUSINESS │
# │ E         ┆ E         ┆ ETYPE     ┆ E         ┆   ┆ LFUNDINGA ┆ OFDIRECTL ┆ OANSUBSID ┆ FUNDSIND │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ MOUNT     ┆ OANORLOAN ┆ YCOST     ┆ ICATOR   │
# │ str       ┆ i64       ┆ i64       ┆ i64       ┆   ┆ ---       ┆ GUA…      ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆ ---       ┆ f64       ┆ str      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ f64       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ A         ┆ 20200803  ┆ 7         ┆ 2         ┆ … ┆ null      ┆ 144000.0  ┆ 19612.8   ┆ NON      │
# │ A         ┆ 20200803  ┆ 7         ┆ 2         ┆ … ┆ null      ┆ 25300.0   ┆ 3445.86   ┆ NON      │
# │ A         ┆ 20200803  ┆ 7         ┆ 2         ┆ … ┆ null      ┆ 100000.0  ┆ 13620.0   ┆ NON      │
# │ A         ┆ 20200803  ┆ 7         ┆ 2         ┆ … ┆ null      ┆ 28600.0   ┆ 3895.32   ┆ NON      │
# │ A         ┆ 20200803  ┆ 7         ┆ 2         ┆ … ┆ null      ┆ 98400.0   ┆ 13402.08  ┆ NON      │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# manual_matches = [(2000003, 54187609)]
# manual_no_matches = [0,1,2,3,4, 2000000, 2000002, 2000004, 2000005, 2000006]

# %%
probable_no_matches = [0, 2000001,2000003]
no_matches = [1,2,3,4, 2000002, 2000004, 2000005, 2000006]

# %%
combined_df[3000][interesting_cols]
# Out:
# shape: (1, 5)
# ┌────────────────────┬───────────────────┬───────────────────┬───────────────────┬─────────────────┐
# │ AWARDEEORRECIPIENT ┆ LEGALENTITYADDRLI ┆ LEGALENTITYCITYNA ┆ LEGALENTITYSTATEC ┆ LEGALENTITYZIP5 │
# │ LEGALENTITYN…      ┆ NE1               ┆ ME                ┆ D                 ┆ ---             │
# │ ---                ┆ ---               ┆ ---               ┆ ---               ┆ i64             │
# │ str                ┆ str               ┆ str               ┆ str               ┆                 │
# ╞════════════════════╪═══════════════════╪═══════════════════╪═══════════════════╪═════════════════╡
# │ Aro Coatings LLC   ┆ 1425 Cornell Rd   ┆ Green Bay         ┆ WI                ┆ 54313           │
# └────────────────────┴───────────────────┴───────────────────┴───────────────────┴─────────────────┘

# %%
combined_df.shape
# Out:
# (3765391, 45)

# %%
# Look for string 'ditzler' in company names
mask = company_names_lower_case.str.contains('aro coat')
potential_matches = apollo_df.filter(mask)
len(potential_matches)
# Out:
# 0

# %%
mask.arg_true()
# Out:
# shape: (4,)
# Series: 'organization_name' [u32]
# [
# 	1248223
# 	1816489
# 	2069428
# 	3694805
# ]

# %%
# print all rows (don't truncate)
# pl.Config.set_tbl_rows(None)
with pl.Config() as cfg:
    cfg.set_tbl_cols(-1)
    cfg.set_tbl_rows(-1)
    display(potential_matches[['organization_name', 'organization_hq_location_city', 'organization_hq_location_state', 'organization_hq_location_postal_code']])
# Out:
# shape: (4, 4)
# ┌────────────────────────┬────────────────────────┬────────────────────────┬───────────────────────┐
# │ organization_name      ┆ organization_hq_locati ┆ organization_hq_locati ┆ organization_hq_locat │
# │ ---                    ┆ on_city                ┆ on_state               ┆ ion_posta…            │
# │ str                    ┆ ---                    ┆ ---                    ┆ ---                   │
# │                        ┆ str                    ┆ str                    ┆ str                   │
# ╞════════════════════════╪════════════════════════╪════════════════════════╪═══════════════════════╡
# │ Farnaz Global          ┆ Atlanta                ┆ Georgia                ┆ 30306                 │
# │ Farnaz Advertising     ┆ null                   ┆ null                   ┆ null                  │
# │ Asssociates            ┆                        ┆                        ┆                       │
# │ FarnazFever            ┆ Mumbai                 ┆ Maharashtra            ┆ 400002                │
# │ Farnaz Makeup & Hair   ┆ null                   ┆ null                   ┆ null                  │
# │ Studio                 ┆                        ┆                        ┆                       │
# └────────────────────────┴────────────────────────┴────────────────────────┴───────────────────────┘

# %%
from rapidfuzz import process

# %%
import time

for sampled_name in sampled_names_lower_case:
    start = time.time()
    extracted = process.extractOne(sampled_name, company_names_lower_case, score_cutoff=90)
    print(f'Matched {sampled_name} to {extracted} in {time.time() - start} seconds')
# process.extractOne(sampled_names_lower_case[0], company_names_lower_case, score_cutoff=90)
# Out:
# Matched destiny construction team, inc. to ('construction construction', 95.0, 9280373) in 31.190216541290283 seconds
# Matched hovhanes papazyan to ('yan', 90.0, 9233834) in 42.667500734329224 seconds
# Matched invisible ink concierge services to ('invisible ink', 90.0, 378104) in 51.62486243247986 seconds
# Matched custom glass of conway, inc. to ('custom glass', 90.0, 4834370) in 50.453418493270874 seconds
# Matched rydate llc to ('ate', 90.0, 5145125) in 34.29480004310608 seconds
# Matched davis unique services to ('unique services', 95.0, 1685182) in 35.82584547996521 seconds
# Matched kailash investments llc to ('kilashee investments llc', 93.61702127659575, 40414668) in 40.041024684906006 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[95], line 5
#       3 for sampled_name in sampled_names_lower_case:
#       4     start = time.time()
# ----> 5     extracted = process.extractOne(sampled_name, company_names_lower_case, score_cutoff=90)
#       6     print(f'Matched {sampled_name} to {extracted} in {time.time() - start} seconds')
#
# File src/rapidfuzz/process_cpp_impl.pyx:683, in rapidfuzz.process_cpp_impl.extractOne()
#
# File src/rapidfuzz/process_cpp_impl.pyx:559, in rapidfuzz.process_cpp_impl.extractOne_list()
#
# File src/rapidfuzz/process_cpp_impl.pyx:445, in rapidfuzz.process_cpp_impl.extractOne_list_f64()
#
# KeyboardInterrupt:

# %%
company_names_lower_case
# Out:
# shape: (54_877_230,)
# Series: 'Company Name' [str]
# [
# 	"comtech"
# 	"tupperware"
# 	"bion diagnostic sciences inc"
# 	"garden cafe"
# 	"garden cafe"
# 	…
# 	"county of hillsborough"
# 	"crabtree & evelyn"
# 	"alternative communication"
# 	"alternative communication"
# 	"siam orchid"
# ]

# %%
4000000/3600
# Out:
# 1111.111111111111

# %%
company_names_lower_case = pl.Series(company_names_lower_case)

# %%
import time

# If the company names are longer than 10 characters then drop the last 5 characters
# company_names_lower_case_shortened = company_names_lower_case.map(lambda x: x if len(x) <= 10 else x[:-5])
company_names_lower_case_shortened = company_names_lower_case.apply(lambda x: x if len(x) <= 10 else x[:-5])


for sampled_name in sampled_names_lower_case:
    start = time.time()
    # Find a perfect match in the company names if it exists

    # Filter to find matches
    matches = company_names_lower_case.filter(company_names_lower_case == sampled_name)

    # Check if matches are not empty and get the first result
    if matches.len() > 0:
        first_match = matches[0]
        print(f'First match: {first_match} for {sampled_name} in {time.time() - start} seconds')
    else:
        # If string is longer than 10 characters retry with a substring
        sampled_name_shortened = sampled_name if len(sampled_name) <= 10 else sampled_name[:-5]
        matches = company_names_lower_case_shortened.filter(company_names_lower_case_shortened == sampled_name_shortened)
        print(f'No matches found for {sampled_name} in {time.time() - start} seconds, retrying')
        
        if matches.len() > 0:
            first_match = matches[0]
            print(f'Shortened match: {first_match} for {sampled_name} in {time.time() - start} seconds')
            
        
    # extracted = process.extractOne(sampled_name, company_names_lower_case, score_cutoff=90)
    # print(f'Matched {sampled_name} to {extracted} in {time.time() - start} seconds')
# process.extractOne(sampled_names_lower_case[0], company_names_lower_case, score_cutoff=90)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[105], line 5
#       1 import time
#       3 # If the company names are longer than 10 characters then drop the last 5 characters
#       4 # company_names_lower_case_shortened = company_names_lower_case.map(lambda x: x if len(x) <= 10 else x[:-5])
# ----> 5 company_names_lower_case_shortened = company_names_lower_case.apply(lambda x: x if len(x) <= 10 else x[:-5])
#       8 for sampled_name in sampled_names_lower_case:
#       9     start = time.time()
#
# AttributeError: 'Series' object has no attribute 'apply'

# %%
4*4*3 * 7.48
# Out:
# 359.04

# %%
import polars as pl
from fuzzywuzzy import process
import random

# Set seed for reproducibility in sampling
random.seed(42)

# Sample 100 random names from 'combined_df' and convert to lowercase
sampled_name = combined_df['AWARDEEORRECIPIENTLEGALENTITYNAME'].sample(n=100, with_replacement=False)#.apply(lambda x: x.lower())

print("A")

# Convert Polars DataFrame to pandas for fuzzy matching
sampled_names_pandas = sampled_name.to_pandas().str.lower()
company_names_pandas = b2b_df['Company Name'].to_pandas().str.lower()
print("B")
# Define a function to find the best match in 'b2b_df'
def get_best_match(name):
    best_match, score = process.extractOne(name, company_names_pandas)
    print(f"Legal Name: {legal_name} -> Best Match Company Name: {company_name}")

    return best_match

# Apply fuzzy matching
matches = sampled_names_pandas.apply(get_best_match)

# Print results
for legal_name, company_name in zip(sampled_names_pandas, matches):
    print(f"Legal Name: {legal_name} -> Best Match Company Name: {company_name}")

# %%
import polars as pl
from fuzzywuzzy import process
import random

# Set seed for reproducibility in sampling
random.seed(42)

# Sample 100 random names from 'combined_df' and convert to lowercase
sampled_name = combined_df['AWARDEEORRECIPIENTLEGALENTITYNAME'].sample(n=100, with_replacement=False)#.apply(lambda x: x.lower())

print("A")

# Convert Polars DataFrame to pandas for fuzzy matching
sampled_names_pandas = sampled_name.to_pandas().str.lower()
company_names_pandas = b2b_df['Company Name'].to_pandas().str.lower()
print("B")
# Define a function to find the best match in 'b2b_df'
def get_best_match(name):
    best_match, score = process.extractOne(name, company_names_pandas)
    print(f"Legal Name: {legal_name} -> Best Match Company Name: {company_name}")

    return best_match

# Apply fuzzy matching
matches = sampled_names_pandas.apply(get_best_match)

# Print results
for legal_name, company_name in zip(sampled_names_pandas, matches):
    print(f"Legal Name: {legal_name} -> Best Match Company Name: {company_name}")
# Out:
# A
# B
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[79], line 25
#      22     return best_match
#      24 # Apply fuzzy matching
# ---> 25 matches = sampled_names_pandas.apply(get_best_match)
#      27 # Print results
#      28 for legal_name, company_name in zip(sampled_names_pandas, matches):
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/apply.py:1137, in SeriesApply.apply_standard(self)
#    1131         values = obj.astype(object)._values
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#    1146     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/.local/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# Cell In[79], line 19, in get_best_match(name)
#      18 def get_best_match(name):
# ---> 19     best_match, score = process.extractOne(name, company_names_pandas)
#      20     print(f"Legal Name: {legal_name} -> Best Match Company Name: {company_name}")
#      22     return best_match
#
# File ~/anaconda3/lib/python3.9/site-packages/fuzzywuzzy/process.py:220, in extractOne(query, choices, processor, scorer, score_cutoff)
#     218 best_list = extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     219 try:
# --> 220     return max(best_list, key=lambda i: i[1])
#     221 except ValueError:
#     222     return None
#
# File ~/anaconda3/lib/python3.9/site-packages/fuzzywuzzy/process.py:110, in extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     108 for key, choice in choices.items():
#     109     processed = pre_processor(processor(choice))
# --> 110     score = scorer(processed_query, processed)
#     111     if score >= score_cutoff:
#     112         yield (choice, score, key)
#
# File ~/anaconda3/lib/python3.9/site-packages/fuzzywuzzy/fuzz.py:288, in WRatio(s1, s2, force_ascii, full_process)
#     285     partial_scale = .6
#     287 if try_partial:
# --> 288     partial = partial_ratio(p1, p2) * partial_scale
#     289     ptsor = partial_token_sort_ratio(p1, p2, full_process=False) \
#     290         * unbase_scale * partial_scale
#     291     ptser = partial_token_set_ratio(p1, p2, full_process=False) \
#     292         * unbase_scale * partial_scale
#
# File ~/anaconda3/lib/python3.9/site-packages/fuzzywuzzy/utils.py:38, in check_for_none.<locals>.decorator(*args, **kwargs)
#      36 if args[0] is None or args[1] is None:
#      37     return 0
# ---> 38 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/fuzzywuzzy/utils.py:29, in check_for_equivalence.<locals>.decorator(*args, **kwargs)
#      27 if args[0] == args[1]:
#      28     return 100
# ---> 29 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/fuzzywuzzy/utils.py:47, in check_empty_string.<locals>.decorator(*args, **kwargs)
#      45 if len(args[0]) == 0 or len(args[1]) == 0:
#      46     return 0
# ---> 47 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/fuzzywuzzy/fuzz.py:61, in partial_ratio(s1, s2)
#      58 long_end = long_start + len(shorter)
#      59 long_substr = longer[long_start:long_end]
# ---> 61 m2 = SequenceMatcher(None, shorter, long_substr)
#      62 r = m2.ratio()
#      63 if r > .995:
#
# KeyboardInterrupt:

# %%
b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# Out:
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,10,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,9,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (9,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,8,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,9,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,9,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (9,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,9,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,9,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,9,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (9,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,9,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])
# /tmp/ipykernel_60045/3965579054.py:1: DtypeWarning: Columns (6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   b2b_df = pd.concat([pd.read_csv(file) for file in b2b_csv_files])

# %%
b2b_df
# Out:
#                         Company Name                    Address          City  \
# 0                            Comtech          9215 151st Ave Ne       Redmond
# 1                         Tupperware             916 S 30th Ave        Yakima
# 2       Bion Diagnostic Sciences Inc  12277 134th Ct Ne Ste 100       Redmond
# 3                        Garden Cafe     18923 Peter Johnson Rd  Mount Vernon
# 4                        Garden Cafe     18923 Peter Johnson Rd  Mount Vernon
# ...                              ...                        ...           ...
# 274082        County Of Hillsborough                400 Mast Rd     Goffstown
# 274083             Crabtree & Evelyn        2 Common Ct Unit B8  North Conway
# 274084     Alternative Communication           3 Bud Way Ste 20        Nashua
# 274085     Alternative Communication           3 Bud Way Ste 20        Nashua
# 274086                   Siam Orchid               12 N Main St       Concord
#
#        State         Zip        County         Phone Contact First  \
# 0         WA  98052-3511          King    4254518138       Eleizer
# 1         WA  98902-4074        Yakima    5099659224          Fred
# 2         WA  98052-2431          King    4258211010         Kelly
# 3         WA  98273-9302        Skagit    3608489189        Martin
# 4         WA  98273-9302        Skagit    3608489189           Dao
# ...      ...         ...           ...           ...           ...
# 274082    NH  03045-2427  Hillsborough  6036275540.0       Richard
# 274083    NH  03860-5440       Carroll  6033564100.0        Romona
# 274084    NH  03063-1700  Hillsborough  6038823100.0        Warren
# 274085    NH  03063-1700  Hillsborough  6038823100.0         Terri
# 274086    NH  03301-4910     Merrimack  6032283633.0           Sui
#
#        Contact Last      Title  Direct Phone                           Email  \
# 0            Scharf  President           NaN       escharf@comtech-group.com
# 1          Lubarsky      Owner           NaN                   fsl31@aol.com
# 2             Walsh    Manager           NaN            kwalsh@polymedco.com
# 3             Tynan    Manager           NaN           mtynan@gardencafe.com
# 4              Choi      Owner           NaN            dchoi@gardencafe.com
# ...             ...        ...           ...                             ...
# 274082        Kerby    Manager  8132725625.0  richard@hillsboroughcounty.org
# 274083       Ropper    Manager           NaN     rropper@crabtree-evelyn.com
# 274084         Kane    Manager           NaN                warren@urnet.com
# 274085     Richards      Owner           NaN                 terri@urnet.com
# 274086          Pan      Owner           NaN                sui@siamfood.com
#
#                          Website Employee Count            Annual Sales  \
# 0              comtechphones.com       10 To 19       $20 To 50 Million
# 1                        aol.com         1 To 4      Less Than $500,000
# 2                  polymedco.com            NaN                     NaN
# 3                 gardencafe.com         5 To 9      Less Than $500,000
# 4                 gardencafe.com         5 To 9      Less Than $500,000
# ...                          ...            ...                     ...
# 274082  hillsboroughcountynh.org         1 To 4                 Unknown
# 274083       crabtree-evelyn.com         5 To 9       $1 To 2.5 Million
# 274084             acstelcom.com         1 To 4       $1 To 2.5 Million
# 274085             acstelcom.com         1 To 4       $1 To 2.5 Million
# 274086            siamorchid.net       20 To 49  $500,000 To $1 Million
#
#        SIC Code                                Industry
# 0        506563  Telecommunication Equip/Syst-Whol/Mfrs
# 1        596304          Home Demonstration-Merchandise
# 2        289900              Chemical Preparations, Nec
# 3        581208                             Restaurants
# 4        581208                             Restaurants
# ...         ...                                     ...
# 274082   912103               Government Offices-County
# 274083   599992             Cosmetics & Perfumes-Retail
# 274084   489903                          Communications
# 274085   489903                          Communications
# 274086   581208                             Restaurants
#
# [54877230 rows x 17 columns]
